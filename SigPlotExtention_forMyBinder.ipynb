# %%
# %load_ext xm_magic
from IPython.display import Image
from IPython.display import Javascript
import numpy as np

# %%
import numpy as np
plot= SigPlot()
plot.overlay_array(np.sin(np.arange(0, 20, 0.01)))
plot.overlay_array(np.cos(np.arange(0, 20, 0.01)))
plot.plot()
# Out:
# SigPlot()

# %%
plot= SigPlot()
plot.overlay_href("https://hub.mybinder.org/user/amatma-jupyter-xm-magic-ke1yityi/files/pulse.tmp")
plot.plot()
# Out:
# SigPlot()

# %%
plot= SigPlot("https://hub.mybinder.org/user/amatma-jupyter-xm-magic-ke1yityi/files/data/sin.tmp")
plot.plot()
# Out:
# SigPlot()

# %%
plot= SigPlot("https://hub.mybinder.org/user/amatma-jupyter-xm-magic-ke1yityi/files/data/sin.tmp")
plot.overlay_href("https://hub.mybinder.org/user/amatma-jupyter-xm-magic-ke1yityi/files/pulse.tmp")
plot.plot()
# Out:
# SigPlot()

# %%
plot=SigPlot("https://hub.mybinder.org/user/amatma-jupyter-xm-magic-ke1yityi/files/penny.prm")
plot.plot()
# Out:
# SigPlot()

# %%
plot=SigPlot("https://hub.mybinder.org/user/amatma-jupyter-xm-magic-ke1yityi/files/penny.prm")
plot.plot("2D")
# Out:
# SigPlot()

# %%
plot=SigPlot()
plot.overlay_array([[1,2,3],[2,3,4],[1,2,3]])
plot.plot("2D")
# Out:
# SigPlot()

# %%
plot=SigPlot()
plot.overlay_array([1,2,3,2,3,4,1,2,3])
plot.plot("2D", subsize=3)
# Out:
# SigPlot()

# %%
plot=SigPlot()
plot.overlay_array([1,2,3,2,3,4,1,2,3])
plot.plot("2D", subsize=5)
# Out:
# SigPlot()
