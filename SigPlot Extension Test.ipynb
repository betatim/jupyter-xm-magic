# %% [markdown]
# # SigPlot Jupyter Notebook Extension!
#
# ## Installation
# ![magic](docs/magic.gif)
# - Install Python 2.6+ or 3.5+
# - Install `pip` (usually bundled with Python)
# - Install Jupyter using `pip`
# - Note: you do not need X-MIDAS installed to use the inline plotting via [SigPlot](https://github.com/lgsinnovations/sigplot).
#
# ```
# pip install jupyter
# ```
#
# - Install the SigPlot Jupyter Notebook extension
#
# ```
# [/path/to/ipython-xm-magic]$ python setup.py install
# ```
# - If you only want the SigPlot interactive plotting, you can just run
#
# $ jupyter notebook
#
# In either case, once the notebook has launched, loading the extension is pretty straightforward, just run
# ```
# %load_ext xm_magic
# ```
#
# and voilà!

# %%
# %load_ext xm_magic
from IPython.display import Image
import numpy as np
# Out:
# The xm_magic extension is already loaded. To reload it, use:
#   %reload_ext xm_magic

# %% [markdown]
# To use the extension, you can either use the exposed functions `xplot` and `xraster` or you can run magic commands via `%xm` as if you were running X-MIDAS.

# %%
import numpy as np
plot= SigPlot()
plot.overlay_array(np.sin(np.arange(0, 20, 0.01)))
plot.overlay_array(np.cos(np.arange(0, 20, 0.01)))
i= Image("docs/SinCos.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot()
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot= SigPlot()
plot.overlay_href("http://sigplot.lgsinnovations.com/dat/pulse.tmp")
print("Plot Image")
i= Image("docs/pulse.png")
display(i)
print("Interactive SigPlot")
plot.plot()
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot= SigPlot("http://sigplot.lgsinnovations.com/dat/sin.tmp")
i= Image("docs/sin.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot()
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot= SigPlot("http://sigplot.lgsinnovations.com/dat/sin.tmp")
plot.overlay_href("http://sigplot.lgsinnovations.com/dat/pulse.tmp")
i= Image("docs/sinPulse.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot()
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot=SigPlot("http://sigplot.lgsinnovations.com/dat/sin.tmp", "http://sigplot.lgsinnovations.com/dat/pulse.tmp",
    np.arange(0, 4, .001)
)
i= Image("docs/sinPulseLine.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot()
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot=SigPlot("http://sigplot.lgsinnovations.com/dat/penny.prm")
i= Image("docs/penny1D.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot()
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot=SigPlot("http://sigplot.lgsinnovations.com/dat/penny.prm")
i= Image("docs/penny2D.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot("2D")
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot=SigPlot()
plot.overlay_array([[1,2,3],[2,3,4],[1,2,3]])
i= Image("docs/2Darray_sub=3.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot("2D")
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot=SigPlot()
plot.overlay_array([1,2,3,2,3,4,1,2,3])
i= Image("docs/2Darray_sub=3.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot("2D", subsize=3)
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()

# %%
plot=SigPlot()
plot.overlay_array([1,2,3,2,3,4,1,2,3])
i= Image("docs/2Darray_sub=5.png")
print("Plot Image")
display(i)
print("Interactive SigPlot")
plot.plot("2D", subsize=5)
# Out:
# Plot Image
# Interactive SigPlot
# SigPlot()
